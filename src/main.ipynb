# %% [markdown]
# ## 1. 初始化

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from scipy.spatial.distance import cdist
from sklearn.metrics import ndcg_score, average_precision_score
import matplotlib.pyplot as plt
import warnings
from tqdm import tqdm
warnings.filterwarnings('ignore')

\
plt.style.use('ggplot')
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 2. 載入資料

# %%
try:
    df_raw = pd.read_csv('../data_after_process/violate_with_type.csv', encoding='utf-8-sig')
    df_coords = pd.read_csv('../data_after_process/unique_locations.csv', encoding='utf-8-sig')
    df_rules = pd.read_csv('../data_after_process/location_rules.csv', encoding='utf-8-sig')
    df_rain = pd.read_csv('../data_after_process/rainfall.csv', encoding='utf-8-sig')
    df_temp = pd.read_csv('../data_after_process/temperature.csv', encoding='utf-8-sig')
except FileNotFoundError as e:
    print(f"找不到檔案: {e}")
    print("請先執行 cluster_locations.py 產生 location_rules.csv")
    exit()
# 建立地點到區域的映射
loc_to_zone = df_rules.set_index('Original_Location')['Zone_ID'].to_dict()
zone_names = df_rules.drop_duplicates('Zone_ID').set_index('Zone_ID')['Zone_Name'].to_dict()

# 處理原始資料
df_raw['Datetime'] = pd.to_datetime(df_raw['舉發日期'], errors='coerce')
df_raw = df_raw.dropna(subset=['Datetime'])
df_raw = df_raw[df_raw['Datetime'].dt.year >= 2023].copy()

# 將地點映射到區域
df_raw['Zone_ID'] = df_raw['違規地點'].map(loc_to_zone)
df_raw = df_raw.dropna(subset=['Zone_ID'])
df_raw['Zone_ID'] = df_raw['Zone_ID'].astype(int)
print(f"篩選後資料: {len(df_raw)} 筆")
# Out:
# 篩選後資料: 27139 筆

# %% [markdown]
# ## 3.建立時間網格 (區域版)

# %%
print("\n建立區域時間網格...")

FREQ = '15min'
start_time = df_raw['Datetime'].min().floor('D')
end_time = df_raw['Datetime'].max().ceil('D')
time_index = pd.date_range(start=start_time, end=end_time, freq=FREQ)

# 取締時段
morning_mask = (time_index.hour >= 9) & ((time_index.hour < 11) | ((time_index.hour == 11) & (time_index.minute <= 30)))
afternoon_mask = (time_index.hour >= 13) & ((time_index.hour < 16) | ((time_index.hour == 16) & (time_index.minute <= 30)))
active_time_index = time_index[morning_mask | afternoon_mask]

# 區域列表
zones = sorted(df_raw['Zone_ID'].unique())
print(f"有效時段數: {len(active_time_index)}")
print(f"區域數: {len(zones)}")

# 建立網格
idx = pd.MultiIndex.from_product([active_time_index, zones], names=['Slot_Start', 'Zone_ID'])
df_grid = pd.DataFrame(index=idx).reset_index()

# 計算每個區域每個時段的取締數
df_raw['Slot_Start'] = df_raw['Datetime'].dt.floor(FREQ)
counts = df_raw.groupby(['Slot_Start', 'Zone_ID']).size().reset_index(name='count_in_slot')

df = pd.merge(df_grid, counts, on=['Slot_Start', 'Zone_ID'], how='left')
df['count_in_slot'] = df['count_in_slot'].fillna(0).astype(int)
df = df.sort_values(['Zone_ID', 'Slot_Start']).reset_index(drop=True)
# Out:
# 建立區域時間網格...
# 有效時段數: 27404
# 區域數: 22

# %% [markdown]
# ## 4.計算區域中心座標

# %%
print("\n計算區域中心座標...")

coords_dict = df_coords.set_index('Location')[['Latitude', 'Longitude']].to_dict('index')

zone_coords = {}
for zone_id in zones:
    zone_locs = df_rules[df_rules['Zone_ID'] == zone_id]['Original_Location'].tolist()
    lats = [coords_dict[loc]['Latitude'] for loc in zone_locs if loc in coords_dict]
    lons = [coords_dict[loc]['Longitude'] for loc in zone_locs if loc in coords_dict]
    if lats and lons:
        zone_coords[zone_id] = {
            'Latitude': np.mean(lats),
            'Longitude': np.mean(lons)
        }

# 計算區域間距離
def haversine(coord1, coord2):
    lat1, lon1 = np.radians(coord1)
    lat2, lon2 = np.radians(coord2)
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    return 6371000 * 2 * np.arcsin(np.sqrt(a))

zone_list = [z for z in zones if z in zone_coords]
zone_to_idx = {z: i for i, z in enumerate(zone_list)}
n_zones = len(zone_list)

dist_matrix = np.zeros((n_zones, n_zones))
for i, z1 in enumerate(zone_list):
    for j, z2 in enumerate(zone_list):
        if i != j:
            c1 = (zone_coords[z1]['Latitude'], zone_coords[z1]['Longitude'])
            c2 = (zone_coords[z2]['Latitude'], zone_coords[z2]['Longitude'])
            dist_matrix[i, j] = haversine(c1, c2)

# 建立鄰近區域
neighbor_map = {}
for i, zone in enumerate(zone_list):
    sorted_indices = np.argsort(dist_matrix[i])
    # 取最近的 5 個鄰居 (排除自己)
    neighbor_map[zone] = [zone_list[idx] for idx in sorted_indices[1:6] if dist_matrix[i, idx] > 0]
print("完成")
# Out:
# 計算區域中心座標...
# 完成

# %% [markdown]
# ## 5. 特徵工程

# %%
print("\n進行特徵工程...")

# 處理降水量缺失值
# 取前兩天和後兩天的平均值補全
df_rain['Precipitation'] = df_rain['Precipitation'].replace('T', np.nan).astype(float)
filled = df_rain['Precipitation'].copy()
for i in range(len(df_rain)):
    if pd.isna(df_rain.loc[i, 'Precipitation']):
        # 前兩天 + 後兩天
        neighbors = []
        
        # 前兩天
        for j in range(1, 3):
            if i - j >= 0:
                neighbors.append(df_rain.loc[i-j, 'Precipitation'])
        
        # 後兩天
        for j in range(1, 3):
            if i + j < len(df_rain):
                neighbors.append(df_rain.loc[i+j, 'Precipitation'])
        
        # 去掉其他 NaN
        neighbors = [x for x in neighbors if pd.notna(x)]
        
        # 計算平均補值
        if len(neighbors) > 0:
            filled.loc[i] = round(np.mean(neighbors), 3)
df_rain['Precipitation'] = filled

# 基礎時間特徵
df['weekday'] = df['Slot_Start'].dt.dayofweek
df['hour'] = df['Slot_Start'].dt.hour
df['minute'] = df['Slot_Start'].dt.minute
df['date'] = df['Slot_Start'].dt.date

df['is_morning_session'] = ((df['hour'] >= 9) & (df['hour'] < 12)).astype(int)
df['is_afternoon_session'] = ((df['hour'] >= 14) & (df['hour'] < 17)).astype(int)

# 週期性編碼
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)
df['weekday_sin'] = np.sin(2 * np.pi * df['weekday'] / 7)
df['weekday_cos'] = np.cos(2 * np.pi * df['weekday'] / 7)

# 先確保 date 型別一致
df['date_str'] = df['date'].astype(str).str.strip()
df_rain['date_str'] = df_rain['date'].astype(str).str.strip()
df_temp['date_str'] = df_temp['date'].astype(str).str.strip()

# 合併降水量
df = df.merge(
    df_rain[['date_str', 'Precipitation']],
    on='date_str',
    how='left'
)

# 合併溫度
df = df.merge(
    df_temp[['date_str', 'temperature']].rename(columns={'temperature': 'temp_mean'}),
    on='date_str',
    how='left'
)

# 填補缺失
df['Precipitation'] = df['Precipitation'].fillna(0.0)
df['temperature'] = df['temp_mean'].fillna(df_temp['temperature'].mean())
df = df.drop(columns=['date_str', 'temp_mean'])


# 場次進度
def calc_session_progress(row):
    h, m = row['hour'], row['minute']
    if 9 <= h < 12:
        start_min, end_min = 9 * 60, 11 * 60 + 30
    else:
        start_min, end_min = 14 * 60, 16 * 60 + 30
    current_min = h * 60 + m
    return (current_min - start_min) / (end_min - start_min)

df['session_progress'] = df.apply(calc_session_progress, axis=1)
# Out:
# 進行特徵工程...

# %%
# 區域靜態特徵
print("計算區域靜態特徵...")
zone_total = df_raw.groupby('Zone_ID').size()
zone_rate = zone_total / zone_total.sum()
df['zone_baseline_risk'] = df['Zone_ID'].map(zone_rate).fillna(0)

# 區域在上午/下午的取締比例
df_raw['is_morning'] = ((df_raw['Datetime'].dt.hour >= 9) & (df_raw['Datetime'].dt.hour < 12)).astype(int)
morning_counts = df_raw[df_raw['is_morning'] == 1].groupby('Zone_ID').size()
afternoon_counts = df_raw[df_raw['is_morning'] == 0].groupby('Zone_ID').size()
total_counts = df_raw.groupby('Zone_ID').size()

zone_morning_ratio = (morning_counts / total_counts).fillna(0.5)
zone_afternoon_ratio = (afternoon_counts / total_counts).fillna(0.5)
df['zone_morning_ratio'] = df['Zone_ID'].map(zone_morning_ratio).fillna(0.5)
df['zone_afternoon_ratio'] = df['Zone_ID'].map(zone_afternoon_ratio).fillna(0.5)

# 區域在每個星期幾的風險
df_raw['weekday'] = df_raw['Datetime'].dt.dayofweek
zone_weekday_avg = df_raw.groupby(['Zone_ID', 'weekday']).size().unstack(fill_value=0)
zone_weekday_avg = zone_weekday_avg / (zone_weekday_avg.sum(axis=1).values.reshape(-1, 1) + 1e-10)

def get_zone_weekday_risk(row):
    zone, wd = row['Zone_ID'], row['weekday']
    if zone in zone_weekday_avg.index:
        return zone_weekday_avg.loc[zone, wd]
    return 0.14

df['zone_weekday_risk'] = df.apply(get_zone_weekday_risk, axis=1)
# Out:
# 計算區域靜態特徵...

# %%
# 歷史特徵
print("計算歷史特徵...")
grouped = df.groupby('Zone_ID')['count_in_slot']
df['lag_1'] = grouped.shift(1).fillna(0)
df['lag_2'] = grouped.shift(2).fillna(0)
df['lag_3'] = grouped.shift(3).fillna(0)
df['lag_4'] = grouped.shift(4).fillna(0)
df['recent_1h_count'] = grouped.shift(1).rolling(window=4, min_periods=1).sum().fillna(0)
df['decay_recent'] = grouped.shift(1).ewm(halflife=2).mean().fillna(0)

# 當天已取締紀錄
print("計算當天已取締紀錄...")
df['date_zone_key'] = df['date'].astype(str) + '_' + df['Zone_ID'].astype(str)
df['today_cumsum'] = df.groupby('date_zone_key')['count_in_slot'].cumsum() - df['count_in_slot']

# 當天全域
df['today_global_cumsum'] = df.groupby('date')['count_in_slot'].cumsum() - df['count_in_slot']
# 當天全域
df['today_global_cumsum'] = df.groupby('date')['count_in_slot'].cumsum() - df['count_in_slot']

# ===== 新增特徵：time_since_last_violation (距離上一次違規的 slot 數) =====
print("計算 time_since_last_violation...")

def compute_time_since_last_violation(group):
    """
    group: 單一 Zone_ID 的資料，已依 Slot_Start 排序
    回傳: 與 group 同長度的 Series，每一列是距離上一次 count_in_slot>0 的 slot 數
    """
    last_idx = None
    result = []
    for i, cnt in enumerate(group['count_in_slot'].values):
        if last_idx is None:
            # 一開始還沒有違規記錄
            result.append(np.nan)   # 先給 NaN，後面再整體補值
        else:
            result.append(i - last_idx)
        if cnt > 0:
            last_idx = i
    return pd.Series(result, index=group.index)

df = df.sort_values(['Zone_ID', 'Slot_Start'])
df['time_since_last_violation'] = df.groupby('Zone_ID', group_keys=False).apply(compute_time_since_last_violation)

# 沒有歷史違規紀錄的區域 / 一開始幾筆，給一個較大的值，例如 100
df['time_since_last_violation'] = df['time_since_last_violation'].fillna(100)

print("計算前一天區域違規數 (Yesterday's Zone Count)...")

# 1. 確保日期格式正確 (轉為 datetime 以便進行加減)
df['temp_date'] = pd.to_datetime(df['date'])

# 2. 計算每一天、每個區域的總違規數
daily_counts = df.groupby(['temp_date', 'Zone_ID'])['count_in_slot'].sum().reset_index(name='zone_yesterday_count')

# 3. 日期偏移：將「今天的違規數」標記為「明天的前一日數據」
# 邏輯：原本是 11/20 的數據，加上 1 天變成 11/21。
# 當我們用 11/21 去 merge 時，就會對應到 11/20 的數據 (即前一天)。
daily_counts['match_date'] = daily_counts['temp_date'] + pd.Timedelta(days=1)

# 4. 合併回主資料集
# 左邊用 (temp_date, Zone_ID)，右邊用 (match_date, Zone_ID)
df = pd.merge(
    df, 
    daily_counts[['match_date', 'Zone_ID', 'zone_yesterday_count']], 
    left_on=['temp_date', 'Zone_ID'], 
    right_on=['match_date', 'Zone_ID'], 
    how='left'
)

# 5. 填補缺失值 (第一天沒有前一天的資料，補 0)
df['zone_yesterday_count'] = df['zone_yesterday_count'].fillna(0)

# 6. 移除暫存欄位
df.drop(columns=['temp_date', 'match_date'], inplace=True, errors='ignore')

print("✅ 特徵新增完成: zone_yesterday_count")
# Out:
# 計算歷史特徵...
# 計算當天已取締紀錄...
# 計算 time_since_last_violation...
# 計算前一天區域違規數 (Yesterday's Zone Count)...
# ✅ 特徵新增完成: zone_yesterday_count

# %%
# 空間特徵
print("計算空間特徵...")
pivot_lag1 = df.pivot(index='Slot_Start', columns='Zone_ID', values='lag_1').fillna(0)

spatial_features = []
for zone in zone_list:
    neighbors = neighbor_map.get(zone, [])
    neighbors = [n for n in neighbors if n in pivot_lag1.columns]
    
    temp = pd.DataFrame({'Slot_Start': pivot_lag1.index, 'Zone_ID': zone})
    
    if neighbors:
        temp['neighbor_lag1_sum'] = pivot_lag1[neighbors].sum(axis=1).values
        temp['neighbor_lag1_mean'] = pivot_lag1[neighbors].mean(axis=1).values
        temp['neighbor_has_event'] = (pivot_lag1[neighbors] > 0).any(axis=1).astype(int).values
        temp['neighbor_event_count'] = (pivot_lag1[neighbors] > 0).sum(axis=1).values
    else:
        temp['neighbor_lag1_sum'] = 0
        temp['neighbor_lag1_mean'] = 0
        temp['neighbor_has_event'] = 0
        temp['neighbor_event_count'] = 0
    
    spatial_features.append(temp)

df_spatial = pd.concat(spatial_features, ignore_index=True)
df = pd.merge(df, df_spatial, on=['Slot_Start', 'Zone_ID'], how='left')

# 填補空值
spatial_cols = ['neighbor_lag1_sum', 'neighbor_lag1_mean', 'neighbor_has_event', 'neighbor_event_count']
df[spatial_cols] = df[spatial_cols].fillna(0)
# Out:
# 計算空間特徵...

# %% [markdown]
# ## 6.進階特徵工程

# %%
print("計算進階特徵...")

# 同星期幾 + 同時段的歷史取締率
df_raw['hour'] = df_raw['Datetime'].dt.hour
zone_weekday_hour = df_raw.groupby(['Zone_ID', 'weekday', 'hour']).size().reset_index(name='hist_count')
zone_weekday_hour_total = df_raw.groupby(['weekday', 'hour']).size().reset_index(name='total_count')
zone_weekday_hour = zone_weekday_hour.merge(zone_weekday_hour_total, on=['weekday', 'hour'])
zone_weekday_hour['zone_weekday_hour_rate'] = zone_weekday_hour['hist_count'] / (zone_weekday_hour['total_count'] + 1)

# 合併到主資料
df = df.merge(
    zone_weekday_hour[['Zone_ID', 'weekday', 'hour', 'zone_weekday_hour_rate']], 
    on=['Zone_ID', 'weekday', 'hour'], 
    how='left'
)
df['zone_weekday_hour_rate'] = df['zone_weekday_hour_rate'].fillna(0)

# 鄰居當天累積取締數
print("計算鄰居當天累積取締...")
pivot_today = df.pivot(index='Slot_Start', columns='Zone_ID', values='today_cumsum').fillna(0)

neighbor_today_features = []
for zone in zone_list:
    neighbors = neighbor_map.get(zone, [])
    neighbors = [n for n in neighbors if n in pivot_today.columns]
    
    temp = pd.DataFrame({'Slot_Start': pivot_today.index, 'Zone_ID': zone})
    
    if neighbors:
        temp['neighbor_today_sum'] = pivot_today[neighbors].sum(axis=1).values
        temp['neighbor_today_max'] = pivot_today[neighbors].max(axis=1).values
    else:
        temp['neighbor_today_sum'] = 0
        temp['neighbor_today_max'] = 0
    
    neighbor_today_features.append(temp)

df_neighbor_today = pd.concat(neighbor_today_features, ignore_index=True)
df = pd.merge(df, df_neighbor_today, on=['Slot_Start', 'Zone_ID'], how='left')
df['neighbor_today_sum'] = df['neighbor_today_sum'].fillna(0)
df['neighbor_today_max'] = df['neighbor_today_max'].fillna(0)

# 交互特徵
print("計算交互特徵...")
df['risk_x_morning'] = df['zone_baseline_risk'] * df['is_morning_session']
df['risk_x_afternoon'] = df['zone_baseline_risk'] * df['is_afternoon_session']
df['risk_x_progress'] = df['zone_baseline_risk'] * df['session_progress']
df['weekday_hour_risk'] = df['zone_weekday_risk'] * df['zone_weekday_hour_rate']

# 時間窗口統計特徵
print("計算時間窗口統計...")
# 過去一週同星期幾同時段的取締次數 (用歷史資料估算)
df['slot_key'] = df['weekday'].astype(str) + '_' + df['hour'].astype(str) + '_' + df['minute'].astype(str)
zone_slot_hist = df_raw.copy()
zone_slot_hist['slot_key'] = zone_slot_hist['weekday'].astype(str) + '_' + zone_slot_hist['Datetime'].dt.hour.astype(str) + '_' + zone_slot_hist['Datetime'].dt.minute.astype(str)
zone_slot_count = zone_slot_hist.groupby(['Zone_ID', 'slot_key']).size().reset_index(name='hist_slot_count')
df = df.merge(zone_slot_count, on=['Zone_ID', 'slot_key'], how='left')
df['hist_slot_count'] = df['hist_slot_count'].fillna(0)
# Out:
# 計算進階特徵...
# 計算鄰居當天累積取締...
# 計算交互特徵...
# 計算時間窗口統計...

# %% [markdown]
# ## 7. 預測目標 (預測該場次內是否會被取締)

# %%
# print("\n 建立預測目標 (該場次剩餘時間內是否取締)...")

# # ========== 預測視窗設定 ==========
# # 根據實際停車情境：通常停一整個上午或下午 (約 2.5 小時)
# # window_size = 10 表示預測未來 2.5 小時 (10 個 15 分鐘 slot)
# # 這符合「早上停到中午」或「下午停到放學」的情境
# WINDOW_SIZE = 12  # 2.5 小時 = 一個完整場次
# # ==================================

# print(f"預測視窗: {WINDOW_SIZE} 個時段 = {WINDOW_SIZE * 15} 分鐘 ({WINDOW_SIZE * 15 / 60:.1f} 小時)")

# # 使用 Forward-looking window 計算未來 N 個 slot 的取締數
# indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=WINDOW_SIZE)
# df['future_window_count'] = df.groupby('Zone_ID')['count_in_slot'].rolling(window=indexer, min_periods=1).sum().values
# df['label'] = df['future_window_count'].fillna(0).astype(int)
# df['relevance'] = df['label'].clip(upper=2)

# df_model = df.dropna().copy()
# print(f"模型資料: {len(df_model)} 筆")

print("\n 建立預測目標 (基於場次剩餘時間)...")

# 1. 定義場次 (Session)
# 將時間分為 'AM' (早上場) 和 'PM' (下午場)
# 邏輯：同一天 + 同一場次 = 一個 Group
def get_session_id(row):
    date_str = str(row['date'])
    h = row['hour']
    # 早上場: 09:00 ~ 12:00 (根據您之前的篩選，資料只會到 11:30 或 11:45)
    if h < 12:
        return f"{date_str}_AM"
    # 下午場: 13:00 ~ 16:30
    else:
        return f"{date_str}_PM"

df['session_id'] = df.apply(get_session_id, axis=1)

# 2. 計算該場次「剩餘時間內」的違規總數
# 邏輯：
# 對每個 (Zone_ID, session_id) 群組：
# 當前時間點的 label = (自己 + 自己後面的所有時段) 的違規總數 > 0
# 我們使用反向累加 (Reverse Cumsum) 來實現這個邏輯

print("計算場次內剩餘違規數...")

# 定義一個函數：反轉 -> 累加 -> 再反轉
# 這樣 index i 的值就會是 sum(i, i+1, ..., end)
def calc_remaining_sum(series):
    return series[::-1].cumsum()[::-1]

df['session_remaining_count'] = df.groupby(['Zone_ID', 'session_id'])['count_in_slot'].transform(calc_remaining_sum)

# 3. 定義 Label
# 如果剩餘時間內有任何違規 (>=1)，則標記為 1 (危險)
df['label'] = (df['session_remaining_count'] > 0).astype(int)
df['relevance'] = df['label'] # 相容性欄位

# 檢查一下數據分佈
print(f"預測目標建立完成。")
print("範例數據 (前 5 筆):")
print(df[['Slot_Start', 'Zone_ID', 'count_in_slot', 'session_remaining_count', 'label']].head())

df_model = df.dropna().copy()
print(f"過濾前總資料筆數: {len(df_model)}")

# 1. 過濾月份：只保留學期中 (2-6月, 9-12月)
#    排除寒假 (1月) 和 暑假 (7, 8月)
df_model['month'] = df_model['Slot_Start'].dt.month
semester_months = [3, 4, 5, 6, 9, 10, 11, 12]
df_model = df_model[df_model['month'].isin(semester_months)].copy()
print(f"過濾寒暑假後筆數: {len(df_model)}")

# 2. 過濾週末：只保留平日 (週一至週五)
df_model = df_model[df_model['weekday'] <= 4].copy()
print(f"過濾週末後 (最終訓練資料) 筆數: {len(df_model)}")

# 3. 檢查正樣本比例 (確認沒有因為過濾導致樣本過少)
pos_rate = (df_model['label'] > 0).mean()
print(f"修正後正樣本比例: {pos_rate:.2%}")
print(f"\n模型資料: {len(df_model)} 筆")
# Out:
#  建立預測目標 (基於場次剩餘時間)...
# 計算場次內剩餘違規數...
# 預測目標建立完成。
# 範例數據 (前 5 筆):
#            Slot_Start  Zone_ID  count_in_slot  session_remaining_count  label
# 0 2023-01-03 09:00:00        1              0                        0      0
# 1 2023-01-03 09:15:00        1              0                        0      0
# 2 2023-01-03 09:30:00        1              0                        0      0
# 3 2023-01-03 09:45:00        1              0                        0      0
# 4 2023-01-03 10:00:00        1              0                        0      0
# 過濾前總資料筆數: 602888
# 過濾寒暑假後筆數: 395824
# 過濾週末後 (最終訓練資料) 筆數: 281996
# 修正後正樣本比例: 9.26%
#
# 模型資料: 281996 筆

# %% [markdown]
# ## 8. 特徵選擇與切分

# %%
features = [
    # 基礎時間特徵
    'weekday', 'hour', 'minute',
    'is_morning_session', 'is_afternoon_session',
    'hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos',
    'session_progress',
    # 區域靜態特徵
    'zone_baseline_risk', 'zone_morning_ratio', 'zone_afternoon_ratio', 'zone_weekday_risk',
    # 歷史特徵
    'lag_1', 'lag_2', 'lag_3', 'lag_4',
    'recent_1h_count', 'decay_recent',
    'today_cumsum', 'today_global_cumsum','time_since_last_violation', 'zone_yesterday_count',
    # 空間特徵
    'neighbor_lag1_sum', 'neighbor_lag1_mean', 'neighbor_has_event', 'neighbor_event_count',
    'neighbor_today_sum', 'neighbor_today_max',
    # 進階特徵
    'zone_weekday_hour_rate', 'hist_slot_count',
    # 交互特徵
    'risk_x_morning', 'risk_x_afternoon', 'risk_x_progress', 'weekday_hour_risk',
    # 外部特徵
    'Precipitation', 'temperature'
]

print(f"\n使用 {len(features)} 個特徵")
X = df_model[features]
y = df_model['relevance']
X.to_csv("X_df.csv", index=False, encoding="utf-8")
y.to_csv("Y_df.csv", index=False, encoding="utf-8")

# 時間切分
unique_dates = sorted(df_model['date'].unique())
split_idx = int(len(unique_dates) * 0.8)
split_date = unique_dates[split_idx]

mask_train = df_model['date'] < split_date
mask_test = df_model['date'] >= split_date

X_train, y_train = X[mask_train], y[mask_train]
X_test, y_test = X[mask_test], y[mask_test]
meta_test = df_model[mask_test][['Slot_Start', 'Zone_ID', 'label', 'relevance', 'date']].copy()

train_pos_rate = (df_model[mask_train]['label'] > 0).mean()
test_pos_rate = (df_model[mask_test]['label'] > 0).mean()

print(f"訓練資料: ~ {split_date} ({split_idx} 天)")
print(f"測試資料: {split_date} ~ ({len(unique_dates) - split_idx} 天)")
print(f"訓練集正樣本比例: {train_pos_rate:.2%}")
print(f"測試集正樣本比例: {test_pos_rate:.2%}")
print(f"訓練集: {len(X_train)} 筆, 測試集: {len(X_test)} 筆")
# Out:
# 使用 38 個特徵
# 訓練資料: ~ 2025-05-07 (394 天)
# 測試資料: 2025-05-07 ~ (99 天)
# 訓練集正樣本比例: 9.16%
# 測試集正樣本比例: 9.65%
# 訓練集: 225368 筆, 測試集: 56628 筆

# %% [markdown]
# ## 9. 訓練模型 (二元分類)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import xgboost as xgb

print("\n準備多模型訓練...")

# 將 label 轉為二元 (有取締 = 1, 無取締 = 0)
y_train_binary = (y_train > 0).astype(int)
y_test_binary = (y_test > 0).astype(int)

print(f"訓練集正樣本: {y_train_binary.sum()} ({y_train_binary.mean():.2%})")
print(f"測試集正樣本: {y_test_binary.sum()} ({y_test_binary.mean():.2%})")

# 計算 scale_pos_weight 來處理不平衡
scale_pos_weight = (y_train_binary == 0).sum() / (y_train_binary == 1).sum()
print(f"scale_pos_weight: {scale_pos_weight:.2f}")

# ==========================================
# 1. XGBoost
# ==========================================
print("\n🚀 訓練 XGBoost...")
dtrain = xgb.DMatrix(X_train, label=y_train_binary)
dtest = xgb.DMatrix(X_test, label=y_test_binary)

# 優化後的參數
params_clf = {
    'objective': 'binary:logistic',
    'eval_metric': ['auc', 'logloss'],
    'eta': 0.014606619733897184,  # 降低學習率
    'max_depth': 7,  # 稍微增加深度
    'min_child_weight': 3,  # 增加以減少過擬合
    'subsample': 0.7178358891298525,
    'colsample_bytree': 0.656131353117126,
    'colsample_bylevel': 0.6561490833437753,
    'reg_alpha': 5.850796029715136,  # 增加 L1 正則化
    'reg_lambda': 8.423556833155619,  # 增加 L2 正則化
    'gamma': 1.811078874379255,  # 加入剪枝
    'scale_pos_weight': scale_pos_weight,
    'tree_method': 'hist',
    'seed': 42
}

print("----------------------------")
model = xgb.train(
    params_clf,
    dtrain,
    num_boost_round=800,  # 增加輪數
    evals=[(dtrain, 'train'), (dtest, 'eval')],
    early_stopping_rounds=50,
    verbose_eval=50
)
print("----------------------------")

# 預測機率作為風險分數
meta_test['risk_score_xgb'] = model.predict(dtest)

# ==========================================
# 2. Logistic Regression
# ==========================================
print("\n📏 訓練 Logistic Regression...")
# 線性模型通常需要特徵標準化
model_lr = make_pipeline(
    StandardScaler(),
    LogisticRegression(class_weight='balanced', solver='liblinear', random_state=42)
)
model_lr.fit(X_train, y_train_binary)
meta_test['risk_score_lr'] = model_lr.predict_proba(X_test)[:, 1]

# ==========================================
# 3. Random Forest
# ==========================================
print("\n🌲 訓練 Random Forest...")
model_rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_leaf=4,
    class_weight='balanced',
    n_jobs=-1,
    random_state=42
)
model_rf.fit(X_train, y_train_binary)
meta_test['risk_score_rf'] = model_rf.predict_proba(X_test)[:, 1]

# 預設使用 XGBoost 作為主要輸出 (兼容後續代碼)
meta_test['risk_score'] = meta_test['risk_score_xgb']
# Out:
# 準備多模型訓練...
# 訓練集正樣本: 20645 (9.16%)
# 測試集正樣本: 5465 (9.65%)
# scale_pos_weight: 9.92
#
# 🚀 訓練 XGBoost...
# ----------------------------
# [0]	train-auc:0.78684	train-logloss:0.68944	eval-auc:0.74936	eval-logloss:0.68953
# [50]	train-auc:0.84261	train-logloss:0.57078	eval-auc:0.81203	eval-logloss:0.57242
# [100]	train-auc:0.85006	train-logloss:0.52383	eval-auc:0.81714	eval-logloss:0.52634
# [150]	train-auc:0.85691	train-logloss:0.49975	eval-auc:0.81960	eval-logloss:0.50459
# [200]	train-auc:0.86406	train-logloss:0.48431	eval-auc:0.82234	eval-logloss:0.49156
# [250]	train-auc:0.87046	train-logloss:0.47280	eval-auc:0.82311	eval-logloss:0.48234
# [300]	train-auc:0.87674	train-logloss:0.46310	eval-auc:0.82341	eval-logloss:0.47526
# [350]	train-auc:0.88291	train-logloss:0.45397	eval-auc:0.82338	eval-logloss:0.46819
# [400]	train-auc:0.88821	train-logloss:0.44605	eval-auc:0.82330	eval-logloss:0.46283
# [450]	train-auc:0.89328	train-logloss:0.43871	eval-auc:0.82294	eval-logloss:0.45840
# [500]	train-auc:0.89784	train-logloss:0.43184	eval-auc:0.82256	eval-logloss:0.45479
# [550]	train-auc:0.90200	train-logloss:0.42549	eval-auc:0.82207	eval-logloss:0.45128
# [600]	train-auc:0.90618	train-logloss:0.41901	eval-auc:0.82136	eval-logloss:0.44786
# [650]	train-auc:0.91044	train-logloss:0.41231	eval-auc:0.82090	eval-logloss:0.44363
# [700]	train-auc:0.91410	train-logloss:0.40642	eval-auc:0.82037	eval-logloss:0.43949
# [750]	train-auc:0.91789	train-logloss:0.40014	eval-auc:0.81993	eval-logloss:0.43537
# [799]	train-auc:0.92171	train-logloss:0.39376	eval-auc:0.81896	eval-logloss:0.43240
# ----------------------------
#
# 📏 訓練 Logistic Regression...
#
# 🌲 訓練 Random Forest...

# %% [markdown]
# ## 10. 評估

# %%
# import optuna
# import xgboost as xgb

# # 確保已經安裝 optuna: !pip install optuna

# print("開始 Optuna 自動調參...")

# def objective(trial):
#     # 1. 定義超參數搜尋空間
#     params = {
#         'objective': 'binary:logistic',
#         'eval_metric': 'auc',  # 我們主要優化 AUC
#         'tree_method': 'hist', # 加速訓練
#         'seed': 42,
        
#         # 固定參數 (使用前面計算好的權重)
#         'scale_pos_weight': scale_pos_weight, 
        
#         # === 動態搜尋參數 (Search Space) ===
#         # 學習率 (通常越低越好，但需要更多 round)
#         'eta': trial.suggest_float('eta', 0.01, 0.1, log=True),
        
#         # 樹的深度與複雜度
#         'max_depth': trial.suggest_int('max_depth', 4, 12),
#         'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        
#         # 隨機採樣 (防止過擬合)
#         'subsample': trial.suggest_float('subsample', 0.6, 1.0),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
#         'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.6, 1.0),
        
#         # 正則化 (L1, L2, Gamma)
#         'reg_alpha': trial.suggest_float('reg_alpha', 0, 10.0),
#         'reg_lambda': trial.suggest_float('reg_lambda', 0, 10.0),
#         'gamma': trial.suggest_float('gamma', 0, 5.0),
#     }

#     # 2. 訓練模型 (加入 Pruning 機制，表現不好提早卡掉)
#     pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "eval-auc")

#     model = xgb.train(
#         params,
#         dtrain,
#         num_boost_round=1000,           # 給予足夠的空間讓模型收斂
#         evals=[(dtest, 'eval')],
#         early_stopping_rounds=50,       # 50輪沒進步就停止
#         callbacks=[pruning_callback],
#         verbose_eval=False              # 不印出詳細訓練過程，保持版面乾淨
#     )
    
#     # 回傳最佳分數 (AUC) 給 Optuna
#     return model.best_score

# # 3. 建立 Study 並開始最佳化
# # direction='maximize' 因為我們要讓 AUC 越大越好
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=50) # 跑 50 次實驗，可視時間增加

# # 4. 輸出結果
# print("\n" + "="*50)
# print(f"最佳 AUC: {study.best_value:.4f}")
# print("最佳參數組合:")
# print(study.best_params)
# print("="*50)

# # 5. 使用最佳參數重新訓練最終模型
# print("\n使用最佳參數訓練最終模型...")
# best_params = study.best_params
# best_params['objective'] = 'binary:logistic'
# best_params['eval_metric'] = ['auc', 'logloss']
# best_params['scale_pos_weight'] = scale_pos_weight
# best_params['tree_method'] = 'hist'
# best_params['seed'] = 42

# final_model = xgb.train(
#     best_params,
#     dtrain,
#     num_boost_round=1000,
#     evals=[(dtrain, 'train'), (dtest, 'eval')],
#     early_stopping_rounds=50,
#     verbose_eval=50
# )

# # 預測 (接續原本的流程)
# y_pred_proba = final_model.predict(dtest)
# meta_test['risk_score'] = y_pred_proba

# %%
def precision_at_k(df_res, score_col, k=5):
    precisions = []
    for slot, group in df_res.groupby('Slot_Start'):
        if group['label'].sum() > 0:
            top_k = group.nlargest(k, score_col)
            hits = (top_k['label'] > 0).sum()
            precisions.append(hits / k)
    return np.mean(precisions) if precisions else 0

def hit_rate_at_k(df_res, score_col, k=3):
    hits = 0
    total = 0
    for slot, group in df_res.groupby('Slot_Start'):
        if group['label'].sum() > 0:
            total += 1
            top_k = group.nlargest(k, score_col)
            if (top_k['label'] > 0).any():
                hits += 1
    return hits / total if total > 0 else 0

def calc_ndcg_per_slot(df_res, score_col, k=10):
    ndcg_list = []
    for slot, group in df_res.groupby('Slot_Start'):
        if group['label'].sum() > 0 and len(group) > 1:
            y_true = group['label'].values.reshape(1, -1)
            y_score = group[score_col].values.reshape(1, -1)
            try:
                ndcg_list.append(ndcg_score(y_true, y_score, k=k))
            except:
                pass
    return np.mean(ndcg_list) if ndcg_list else 0

def safe_zone_accuracy(df_res, score_col, bottom_k=5):
    accuracies = []
    for slot, group in df_res.groupby('Slot_Start'):
        bottom_k_zones = group.nsmallest(bottom_k, score_col)
        safe_count = (bottom_k_zones['label'] == 0).sum()
        accuracies.append(safe_count / bottom_k)
    return np.mean(accuracies)

def danger_zone_hit_rate(df_res, score_col, top_k=5):
    """Top K 區域中有取締的比例"""
    hit_rates = []
    for slot, group in df_res.groupby('Slot_Start'):
        top_k_zones = group.nlargest(top_k, score_col)
        hit_count = (top_k_zones['label'] > 0).sum()
        hit_rates.append(hit_count / top_k)
    return np.mean(hit_rates)

# 計算指標
active_slots = meta_test.groupby('Slot_Start')['label'].sum()
active_slot_count = (active_slots > 0).sum()
total_slots = len(active_slots)

print(f"\n📊 資料統計:")
print(f"   🔹 區域數: {len(zones)}")
print(f"   🔹 測試時段數: {total_slots}")
print(f"   🔹 有取締的時段: {active_slot_count} ({active_slot_count/total_slots:.1%})")

models_to_eval = {
    'XGBoost': 'risk_score_xgb',
    'Logistic Regression': 'risk_score_lr',
    'Random Forest': 'risk_score_rf'
}

for model_name, score_col in models_to_eval.items():
    print(f"\n{'='*20} {model_name} 評估 {'='*20}")
    
    print(f"\n📊 Precision@K:")
    print(f"   🔹 Precision@3: {precision_at_k(meta_test, score_col, 3):.2%}")
    print(f"   🔹 Precision@5: {precision_at_k(meta_test, score_col, 5):.2%}")

    print(f"\n📊 Hit Rate@K (在有取締的時段，Top K 至少命中一個的比例):")
    print(f"   🔹 Hit Rate@3: {hit_rate_at_k(meta_test, score_col, 3):.2%}")
    print(f"   🔹 Hit Rate@5: {hit_rate_at_k(meta_test, score_col, 5):.2%}")
    print(f"   🔹 Hit Rate@10: {hit_rate_at_k(meta_test, score_col, 10):.2%}")

    print(f"\n📊 排名品質:")
    print(f"   🔹 NDCG@5: {calc_ndcg_per_slot(meta_test, score_col, 5):.4f}")
    print(f"   🔹 NDCG@10: {calc_ndcg_per_slot(meta_test, score_col, 10):.4f}")

    # 計算隨機基準線
    random_baseline = 1 - test_pos_rate  # 隨機選的安全率 = 負樣本比例

    print(f"\n📊 安全區 vs 危險區 (模型區分能力):")
    print(f"   🔹 隨機選 5 個的安全率 (基準線): {random_baseline:.2%}")
    print(f"   🔹 模型 Bottom 5 安全率: {safe_zone_accuracy(meta_test, score_col, 5):.2%}")
    print(f"   🔹 模型 Top 5 安全率: {1 - danger_zone_hit_rate(meta_test, score_col, 5):.2%}")
    print(f"   🔹 模型 Top 5 危險率: {danger_zone_hit_rate(meta_test, score_col, 5):.2%}")
    print(f"   ────────────────────────────────")
    safe_bottom = safe_zone_accuracy(meta_test, score_col, 5)
    safe_top = 1 - danger_zone_hit_rate(meta_test, score_col, 5)
    print(f"   📈 區分能力 = {safe_bottom:.2%} - {safe_top:.2%} = {(safe_bottom - safe_top):.2%}")
# Out:
# 📊 資料統計:
#    🔹 區域數: 22
#    🔹 測試時段數: 2574
#    🔹 有取締的時段: 1474 (57.3%)
#
# ==================== XGBoost 評估 ====================
#
# 📊 Precision@K:
#    🔹 Precision@3: 35.50%
#    🔹 Precision@5: 29.95%
#
# 📊 Hit Rate@K (在有取締的時段，Top K 至少命中一個的比例):
#    🔹 Hit Rate@3: 72.73%
#    🔹 Hit Rate@5: 83.04%
#    🔹 Hit Rate@10: 94.30%
#
# 📊 排名品質:
#    🔹 NDCG@5: 0.4878
#    🔹 NDCG@10: 0.5756
#
# 📊 安全區 vs 危險區 (模型區分能力):
#    🔹 隨機選 5 個的安全率 (基準線): 90.35%
#    🔹 模型 Bottom 5 安全率: 95.76%
#    🔹 模型 Top 5 安全率: 82.85%
#    🔹 模型 Top 5 危險率: 17.15%
#    ────────────────────────────────
#    📈 區分能力 = 95.76% - 82.85% = 12.91%
#
# ==================== Logistic Regression 評估 ====================
#
# 📊 Precision@K:
#    🔹 Precision@3: 29.87%
#    🔹 Precision@5: 27.20%
#
# 📊 Hit Rate@K (在有取締的時段，Top K 至少命中一個的比例):
#    🔹 Hit Rate@3: 65.33%
#    🔹 Hit Rate@5: 80.66%
#    🔹 Hit Rate@10: 95.05%
#
# 📊 排名品質:
#    🔹 NDCG@5: 0.4221
#    🔹 NDCG@10: 0.5159
#
# 📊 安全區 vs 危險區 (模型區分能力):
#    🔹 隨機選 5 個的安全率 (基準線): 90.35%
#    🔹 模型 Bottom 5 安全率: 95.45%
#    🔹 模型 Top 5 安全率: 84.42%
#    🔹 模型 Top 5 危險率: 15.58%
#    ────────────────────────────────
#    📈 區分能力 = 95.45% - 84.42% = 11.03%
#
# ==================== Random Forest 評估 ====================
#
# 📊 Precision@K:
#    🔹 Precision@3: 35.30%
#    🔹 Precision@5: 30.01%
#
# 📊 Hit Rate@K (在有取締的時段，Top K 至少命中一個的比例):
#    🔹 Hit Rate@3: 72.32%
#    🔹 Hit Rate@5: 83.58%
#    🔹 Hit Rate@10: 95.12%
#
# 📊 排名品質:
#    🔹 NDCG@5: 0.4835
#    🔹 NDCG@10: 0.5692
#
# 📊 安全區 vs 危險區 (模型區分能力):
#    🔹 隨機選 5 個的安全率 (基準線): 90.35%
#    🔹 模型 Bottom 5 安全率: 95.91%
#    🔹 模型 Top 5 安全率: 82.81%
#    🔹 模型 Top 5 危險率: 17.19%
#    ────────────────────────────────
#    📈 區分能力 = 95.91% - 82.81% = 13.10%

# %% [markdown]
# ## 11. 儲存模型

# %%
model.save_model('parking_risk_model_v4_zone.json')

# 儲存區域名稱對照表
zone_info = []
for zone_id in zones:
    zone_name = zone_names.get(zone_id, f'Zone_{zone_id}')
    zone_locs = df_rules[df_rules['Zone_ID'] == zone_id]['Original_Location'].tolist()
    zone_info.append({
        'Zone_ID': zone_id,
        'Zone_Name': zone_name,
        'Locations': ', '.join(zone_locs)
    })

pd.DataFrame(zone_info).to_csv('zone_info.csv', index=False, encoding='utf-8-sig')

print("\n模型已儲存: parking_risk_model_v4_zone.json")
print("區域資訊已儲存: zone_info.csv")
# Out:
# 模型已儲存: parking_risk_model_v4_zone.json
# 區域資訊已儲存: zone_info.csv

# %% [markdown]
# ## 13. 範例輸出

# %%
# ========== 自訂時間設定 ==========
# 設定為 None 則使用測試集最新時段，或指定特定時間
# 格式: "YYYY-MM-DD HH:MM" (會自動對齊到 15 分鐘)
# 例如: CUSTOM_SAMPLE_TIME = "2024-10-15 09:30"
CUSTOM_SAMPLE_TIME = "2025-11-21 09:00"  # 修改這裡來指定時間
# ==================================

if CUSTOM_SAMPLE_TIME is not None:
    # 使用自訂時間
    custom_dt = pd.to_datetime(CUSTOM_SAMPLE_TIME)
    sample_slot = custom_dt.floor('15min')
    
    # 檢查是否在測試集範圍內
    if sample_slot in meta_test['Slot_Start'].values:
        sample_data_base = meta_test[meta_test['Slot_Start'] == sample_slot].copy()
        print(f"\n✅ 使用自訂時間: {CUSTOM_SAMPLE_TIME}")
    else:
        print(f"\n⚠️ 自訂時間 {CUSTOM_SAMPLE_TIME} 不在測試集範圍內")
        print(f"   測試集範圍: {meta_test['Slot_Start'].min()} ~ {meta_test['Slot_Start'].max()}")
        print("   改用測試集最新時段...")
        latest_date = meta_test['date'].max()
        latest_data = meta_test[meta_test['date'] == latest_date]
        sample_slot = latest_data['Slot_Start'].min()
        sample_data_base = latest_data[latest_data['Slot_Start'] == sample_slot].copy()
else:
    # 使用測試集最新時段
    latest_date = meta_test['date'].max()
    latest_data = meta_test[meta_test['date'] == latest_date]
    sample_slot = latest_data['Slot_Start'].min()
    sample_data_base = latest_data[latest_data['Slot_Start'] == sample_slot].copy()

print(f"\n⏰ 時段: {sample_slot}")

models_to_show = {
    'XGBoost': 'risk_score_xgb',
    'Logistic Regression': 'risk_score_lr',
    'Random Forest': 'risk_score_rf'
}

for model_name, score_col in models_to_show.items():
    print(f"\n{'='*20} {model_name} 預測結果 {'='*20}")
    
    # 複製並排序
    sample_data = sample_data_base.copy()
    sample_data = sample_data.sort_values(score_col, ascending=False)

    print(f"\n🔴 最危險 Top 10 區域:")
    for i, (_, row) in enumerate(sample_data.head(10).iterrows()):
        zone_name = zone_names.get(row['Zone_ID'], f"Zone_{row['Zone_ID']}")
        actual = "⚠️ 有取締" if row['label'] > 0 else ""
        print(f"   {i+1}. {zone_name:<15} 分數: {row[score_col]:.4f} {actual}")

    print(f"\n🟢 最安全 Top 10 區域:")
    for i, (_, row) in enumerate(sample_data.tail(10).iloc[::-1].iterrows()):
        zone_name = zone_names.get(row['Zone_ID'], f"Zone_{row['Zone_ID']}")
        actual = "⚠️ 有取締" if row['label'] > 0 else ""
        print(f"   {i+1}. {zone_name:<15} 分數: {row[score_col]:.4f} {actual}")

    # 該時段的統計
    top5_danger = sample_data.head(5)
    bot5_safe = sample_data.tail(5)
    print(f"\n📈 此時段統計 ({model_name}):")
    print(f"   🔹 Top 5 危險區命中: {(top5_danger['label'] > 0).sum()}/5 ({(top5_danger['label'] > 0).mean():.0%})")
    print(f"   🔹 Bottom 5 安全區正確: {(bot5_safe['label'] == 0).sum()}/5 ({(bot5_safe['label'] == 0).mean():.0%})")
    print(f"   🔹 此時段總取締區域數: {(sample_data['label'] > 0).sum()}/{len(sample_data)}")
# Out:
# ✅ 使用自訂時間: 2025-11-21 09:00
#
# ⏰ 時段: 2025-11-21 09:00:00
#
# ==================== XGBoost 預測結果 ====================
#
# 🔴 最危險 Top 10 區域:
#    1. 電資附近            分數: 0.8775 ⚠️ 有取締
#    2. 翠亨宿舍西           分數: 0.8480
#    3. L停附近            分數: 0.8213 ⚠️ 有取締
#    4. 理工區             分數: 0.8148 ⚠️ 有取締
#    5. 武嶺裡面            分數: 0.8088
#    6. 社科院             分數: 0.7535
#    7. 武嶺外面            分數: 0.6812
#    8. 藝術學院            分數: 0.6805 ⚠️ 有取締
#    9. 大門口附近           分數: 0.6342
#    10. 管停              分數: 0.6271 ⚠️ 有取締
#
# 🟢 最安全 Top 10 區域:
#    1. 運動場區            分數: 0.0071
#    2. 翠嶺道             分數: 0.2594
#    3. 圖資區             分數: 0.3133
#    4. 文學院             分數: 0.3233
#    5. 生科附近            分數: 0.3738
#    6. 行政大樓            分數: 0.3995
#    7. 海科院             分數: 0.5041
#    8. 活動中心區           分數: 0.5118
#    9. 管院              分數: 0.5258
#    10. 翠亨宿舍東           分數: 0.5527
#
# 📈 此時段統計 (XGBoost):
#    🔹 Top 5 危險區命中: 3/5 (60%)
#    🔹 Bottom 5 安全區正確: 5/5 (100%)
#    🔹 此時段總取締區域數: 5/22
#
# ==================== Logistic Regression 預測結果 ====================
#
# 🔴 最危險 Top 10 區域:
#    1. L停附近            分數: 0.8387 ⚠️ 有取締
#    2. 電資附近            分數: 0.8387 ⚠️ 有取締
#    3. 翠亨宿舍西           分數: 0.7812
#    4. 活動中心區           分數: 0.7556
#    5. 社科院             分數: 0.7366
#    6. 管停              分數: 0.7117 ⚠️ 有取締
#    7. 武嶺裡面            分數: 0.7107
#    8. 大門口附近           分數: 0.6969
#    9. 理工區             分數: 0.6930 ⚠️ 有取締
#    10. 生科附近            分數: 0.6791
#
# 🟢 最安全 Top 10 區域:
#    1. 翠嶺道             分數: 0.4100
#    2. 文學院             分數: 0.4647
#    3. 海工館             分數: 0.5203
#    4. 運動場區            分數: 0.5316
#    5. 圖資區             分數: 0.5404
#    6. 行政大樓            分數: 0.5715
#    7. 翠亨宿舍東           分數: 0.5843
#    8. 管院              分數: 0.6146
#    9. 武嶺外面            分數: 0.6368
#    10. 海科院             分數: 0.6401
#
# 📈 此時段統計 (Logistic Regression):
#    🔹 Top 5 危險區命中: 2/5 (40%)
#    🔹 Bottom 5 安全區正確: 5/5 (100%)
#    🔹 此時段總取締區域數: 5/22
#
# ==================== Random Forest 預測結果 ====================
#
# 🔴 最危險 Top 10 區域:
#    1. 電資附近            分數: 0.8409 ⚠️ 有取締
#    2. 翠亨宿舍西           分數: 0.8097
#    3. 理工區             分數: 0.8079 ⚠️ 有取締
#    4. L停附近            分數: 0.8045 ⚠️ 有取締
#    5. 武嶺裡面            分數: 0.7651
#    6. 社科院             分數: 0.7356
#    7. 管停              分數: 0.6879 ⚠️ 有取締
#    8. 藝術學院            分數: 0.6716 ⚠️ 有取締
#    9. 大門口附近           分數: 0.6641
#    10. 武嶺外面            分數: 0.6449
#
# 🟢 最安全 Top 10 區域:
#    1. 運動場區            分數: 0.0506
#    2. 翠嶺道             分數: 0.3722
#    3. 文學院             分數: 0.4435
#    4. 行政大樓            分數: 0.4575
#    5. 圖資區             分數: 0.5019
#    6. 翠亨宿舍東           分數: 0.5086
#    7. 生科附近            分數: 0.5183
#    8. 活動中心區           分數: 0.5596
#    9. 海科院             分數: 0.5887
#    10. 理學院             分數: 0.5911
#
# 📈 此時段統計 (Random Forest):
#    🔹 Top 5 危險區命中: 3/5 (60%)
#    🔹 Bottom 5 安全區正確: 5/5 (100%)
#    🔹 此時段總取締區域數: 5/22

# %% [markdown]
# ## 14. R² 與模型解釋力分析

# %%
from sklearn.metrics import r2_score, brier_score_loss, log_loss, roc_auc_score
from sklearn.calibration import calibration_curve
from scipy.stats import spearmanr, pearsonr
from sklearn.metrics import explained_variance_score

print("=" * 70)
print("📊 多模型 R² 與解釋力分析")
print("=" * 70)

y_test_np = y_test_binary.values
null_prob = y_train_binary.mean()

models_to_analyze = {
    'XGBoost': 'risk_score_xgb',
    'Logistic Regression': 'risk_score_lr',
    'Random Forest': 'risk_score_rf'
}

for model_name, score_col in models_to_analyze.items():
    print(f"\n\n{'#'*30}")
    print(f"   模型: {model_name}")
    print(f"{'#'*30}")
    
    # 取得該模型的預測分數
    y_pred_np = meta_test[score_col].values

    # ==========================================
    # 1. 核心指標：AUC-ROC
    # ==========================================
    auc_score = roc_auc_score(y_test_np, y_pred_np)
    print(f"\n📈 核心分類指標:")
    print(f"   🔹 AUC-ROC: {auc_score:.4f}")

    # ==========================================
    # 2. 機率校準分析
    # ==========================================
    print(f"\n📈 機率校準分析:")
    print(f"   🔹 預測機率平均: {y_pred_np.mean():.2%}")
    prob_diff = abs(y_test_np.mean() - y_pred_np.mean())
    if prob_diff > 0.05:
        print(f"   ⚠️ 機率未校準 (差距 {prob_diff:.2%})")
    else:
        print(f"   ✅ 機率校準良好")

    # ==========================================
    # 3. 排名相關性 (Spearman)
    # ==========================================
    correlations = []
    for slot, group in meta_test.groupby('Slot_Start'):
        if len(group) > 5 and group['label'].sum() > 0:
            pred_rank = group[score_col].rank(ascending=False)
            actual_rank = group['label'].rank(ascending=False, method='average')
            corr, _ = spearmanr(pred_rank, actual_rank)
            if not np.isnan(corr):
                correlations.append(corr)

    avg_spearman = np.mean(correlations) if correlations else 0
    rank_r2 = avg_spearman ** 2

    print(f"\n📈 排名相關性 (Spearman):")
    print(f"   🔹 平均 Spearman ρ: {avg_spearman:.4f}")
    print(f"   🔹 排名決定係數 ρ²: {rank_r2:.4f}")

    # ==========================================
    # 4. 區域層級分析 (Pearson)
    # ==========================================
    zone_stats = meta_test.groupby('Zone_ID').agg({
        score_col: 'mean',
        'label': 'mean'
    }).reset_index()

    zone_corr, zone_p = pearsonr(zone_stats['label'], zone_stats[score_col])
    zone_r2 = zone_corr ** 2

    print(f"\n📈 區域層級分析:")
    print(f"   🔹 區域 Pearson 相關: {zone_corr:.4f}")
    print(f"   🔹 區域相關 R²: {zone_r2:.4f}")

    # ==========================================
    # 5. 分組校準 (Calibration by Decile)
    # ==========================================
    meta_temp = meta_test.copy()
    meta_temp['pred_decile'] = pd.qcut(meta_temp[score_col], q=10, labels=False, duplicates='drop')
    calibration_df = meta_temp.groupby('pred_decile').agg({
        score_col: 'mean',
        'label': ['mean', 'count']
    }).round(4)
    calibration_df.columns = ['預測機率', '實際正率', '樣本數']
    
    pred_by_group = calibration_df['預測機率'].values
    actual_by_group = calibration_df['實際正率'].values
    if len(pred_by_group) > 2:
        group_corr, _ = pearsonr(pred_by_group, actual_by_group)
        group_r2 = group_corr ** 2
    else:
        group_r2 = 0

    # ==========================================
    # 總結表格
    # ==========================================
    # 評價邏輯
    eval_auc = '✅ 優秀' if auc_score > 0.8 else ('⚠️ 普通' if auc_score > 0.7 else '❌ 差')
    eval_spearman = '✅ 有效' if avg_spearman > 0.2 else '⚠️ 弱'
    eval_pearson = '✅ 顯著' if zone_p < 0.05 else '❌ 不顯著'
    eval_calib = '✅ 單調' if group_r2 > 0.8 else '⚠️ 待改進'

    print(f"""
    ┌────────────────────────────────────────────────────────────────┐
    │  指標 ({model_name:<19})│  數值      │  評價              │
    ├────────────────────────────────────────────────────────────────┤
    │  AUC-ROC (分類能力)            │  {auc_score:>6.4f}    │  {eval_auc:<16}  │
    │  Spearman ρ (排名相關)         │  {avg_spearman:>6.4f}    │  {eval_spearman:<16}  │
    │  區域 Pearson r                │  {zone_corr:>6.4f}    │  {eval_pearson:<16}  │
    │  分組校準 R²                   │  {group_r2:>6.4f} │ {eval_calib:<16} │
    └────────────────────────────────────────────────────────────────┘
    """)
# Out:
# ======================================================================
# 📊 多模型 R² 與解釋力分析
# ======================================================================
#
#
# ##############################
#    模型: XGBoost
# ##############################
#
# 📈 核心分類指標:
#    🔹 AUC-ROC: 0.8190
#
# 📈 機率校準分析:
#    🔹 預測機率平均: 30.69%
#    ⚠️ 機率未校準 (差距 21.04%)
#
# 📈 排名相關性 (Spearman):
#    🔹 平均 Spearman ρ: 0.2439
#    🔹 排名決定係數 ρ²: 0.0595
#
# 📈 區域層級分析:
#    🔹 區域 Pearson 相關: 0.7873
#    🔹 區域相關 R²: 0.6199
#
#     ┌────────────────────────────────────────────────────────────────┐
#     │  指標 (XGBoost            )│  數值      │  評價              │
#     ├────────────────────────────────────────────────────────────────┤
#     │  AUC-ROC (分類能力)            │  0.8190    │  ✅ 優秀              │
#     │  Spearman ρ (排名相關)         │  0.2439    │  ✅ 有效              │
#     │  區域 Pearson r                │  0.7873    │  ✅ 顯著              │
#     │  分組校準 R²                   │  0.9261 │ ✅ 單調             │
#     └────────────────────────────────────────────────────────────────┘
#
#
#
# ##############################
#    模型: Logistic Regression
# ##############################
#
# 📈 核心分類指標:
#    🔹 AUC-ROC: 0.7874
#
# 📈 機率校準分析:
#    🔹 預測機率平均: 40.54%
#    ⚠️ 機率未校準 (差距 30.89%)
#
# 📈 排名相關性 (Spearman):
#    🔹 平均 Spearman ρ: 0.2101
#    🔹 排名決定係數 ρ²: 0.0441
#
# 📈 區域層級分析:
#    🔹 區域 Pearson 相關: 0.7469
#    🔹 區域相關 R²: 0.5578
#
#     ┌────────────────────────────────────────────────────────────────┐
#     │  指標 (Logistic Regression)│  數值      │  評價              │
#     ├────────────────────────────────────────────────────────────────┤
#     │  AUC-ROC (分類能力)            │  0.7874    │  ⚠️ 普通             │
#     │  Spearman ρ (排名相關)         │  0.2101    │  ✅ 有效              │
#     │  區域 Pearson r                │  0.7469    │  ✅ 顯著              │
#     │  分組校準 R²                   │  0.9050 │ ✅ 單調             │
#     └────────────────────────────────────────────────────────────────┘
#
#
#
# ##############################
#    模型: Random Forest
# ##############################
#
# 📈 核心分類指標:
#    🔹 AUC-ROC: 0.8148
#
# 📈 機率校準分析:
#    🔹 預測機率平均: 35.05%
#    ⚠️ 機率未校準 (差距 25.40%)
#
# 📈 排名相關性 (Spearman):
#    🔹 平均 Spearman ρ: 0.2453
#    🔹 排名決定係數 ρ²: 0.0602
#
# 📈 區域層級分析:
#    🔹 區域 Pearson 相關: 0.8108
#    🔹 區域相關 R²: 0.6574
#
#     ┌────────────────────────────────────────────────────────────────┐
#     │  指標 (Random Forest      )│  數值      │  評價              │
#     ├────────────────────────────────────────────────────────────────┤
#     │  AUC-ROC (分類能力)            │  0.8148    │  ✅ 優秀              │
#     │  Spearman ρ (排名相關)         │  0.2453    │  ✅ 有效              │
#     │  區域 Pearson r                │  0.8108    │  ✅ 顯著              │
#     │  分組校準 R²                   │  0.8870 │ ✅ 單調             │
#     └────────────────────────────────────────────────────────────────┘

# %%
from sklearn.metrics import confusion_matrix, precision_recall_curve, auc, classification_report

FIXED_THRESHOLD = 0.6  # 統一使用 0.7

for model_name, score_col in models_to_analyze.items():
    print(f"\n\n{'#'*30}")
    print(f"   模型: {model_name}")
    print(f"{'#'*30}")
    
    y_pred_np = meta_test[score_col].values
    y_pred_proba = y_pred_np  # 已是機率值

    print("\n" + "=" * 70)
    print("📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC 分析")
    print("=" * 70)

    # 1. 只用 threshold = 0.7
    thr = FIXED_THRESHOLD
    y_pred_label = (y_pred_proba > thr).astype(int)
    print(f"Threshold: {thr}")
    print(classification_report(y_test_binary, y_pred_label, digits=4))

    # 2. Confusion Matrix（同樣用 0.7）
    cm = confusion_matrix(y_test_binary, y_pred_label)
    tn, fp, fn, tp = cm.ravel()

    print(f"\n📊 Confusion Matrix (threshold={thr}):")
    print("          Pred 0    Pred 1")
    print(f"True 0   {tn:7d}  {fp:7d}")
    print(f"True 1   {fn:7d}  {tp:7d}")

    # 3. Precision-Recall 曲線與 PR-AUC（和 threshold 無關）
    precision, recall, pr_thresholds = precision_recall_curve(y_test_binary, y_pred_np)
    pr_auc = auc(recall, precision)

    print("\n📊 Precision-Recall AUC:")
    print(f"   🔹 PR-AUC: {pr_auc:.4f}")
    print("   📝 解釋: 在不同 threshold 下 precision-recall 的平均表現")
    print("      對高度不平衡資料，比 ROC-AUC 更有參考價值")

    # 4. 在 threshold = 0.7 下的概覽
    pos_pred = (y_pred_label == 1).sum()
    print(f"\n📊 在 threshold = {thr} 下的概覽:")
    print(f"   🔹 正樣本實際比例: {y_test_binary.mean():.2%}")
    print(f"   🔹 預測為正樣本的比例: {pos_pred/len(y_test_binary):.2%}")
    print(f"   🔹 TP: {tp}, FP: {fp}, FN: {fn}, TN: {tn}")
# Out:
# ##############################
#    模型: XGBoost
# ##############################
#
# ======================================================================
# 📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC 分析
# ======================================================================
# Threshold: 0.6
#               precision    recall  f1-score   support
#
#            0     0.9459    0.8674    0.9049     51163
#            1     0.3014    0.5358    0.3858      5465
#
#     accuracy                         0.8354     56628
#    macro avg     0.6237    0.7016    0.6454     56628
# weighted avg     0.8837    0.8354    0.8548     56628
#
#
# 📊 Confusion Matrix (threshold=0.6):
#           Pred 0    Pred 1
# True 0     44377     6786
# True 1      2537     2928
#
# 📊 Precision-Recall AUC:
#    🔹 PR-AUC: 0.3474
#    📝 解釋: 在不同 threshold 下 precision-recall 的平均表現
#       對高度不平衡資料，比 ROC-AUC 更有參考價值
#
# 📊 在 threshold = 0.6 下的概覽:
#    🔹 正樣本實際比例: 9.65%
#    🔹 預測為正樣本的比例: 17.15%
#    🔹 TP: 2928, FP: 6786, FN: 2537, TN: 44377
#
#
# ##############################
#    模型: Logistic Regression
# ##############################
#
# ======================================================================
# 📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC 分析
# ======================================================================
# Threshold: 0.6
#               precision    recall  f1-score   support
#
#            0     0.9477    0.8033    0.8695     51163
#            1     0.2410    0.5848    0.3413      5465
#
#     accuracy                         0.7822     56628
#    macro avg     0.5943    0.6940    0.6054     56628
# weighted avg     0.8795    0.7822    0.8185     56628
#
#
# 📊 Confusion Matrix (threshold=0.6):
#           Pred 0    Pred 1
# True 0     41097    10066
# True 1      2269     3196
#
# 📊 Precision-Recall AUC:
#    🔹 PR-AUC: 0.2993
#    📝 解釋: 在不同 threshold 下 precision-recall 的平均表現
#       對高度不平衡資料，比 ROC-AUC 更有參考價值
#
# 📊 在 threshold = 0.6 下的概覽:
#    🔹 正樣本實際比例: 9.65%
#    🔹 預測為正樣本的比例: 23.42%
#    🔹 TP: 3196, FP: 10066, FN: 2269, TN: 41097
#
#
# ##############################
#    模型: Random Forest
# ##############################
#
# ======================================================================
# 📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC 分析
# ======================================================================
# Threshold: 0.6
#               precision    recall  f1-score   support
#
#            0     0.9433    0.8725    0.9065     51163
#            1     0.2989    0.5089    0.3766      5465
#
#     accuracy                         0.8374     56628
#    macro avg     0.6211    0.6907    0.6416     56628
# weighted avg     0.8811    0.8374    0.8554     56628
#
#
# 📊 Confusion Matrix (threshold=0.6):
#           Pred 0    Pred 1
# True 0     44641     6522
# True 1      2684     2781
#
# 📊 Precision-Recall AUC:
#    🔹 PR-AUC: 0.3322
#    📝 解釋: 在不同 threshold 下 precision-recall 的平均表現
#       對高度不平衡資料，比 ROC-AUC 更有參考價值
#
# 📊 在 threshold = 0.6 下的概覽:
#    🔹 正樣本實際比例: 9.65%
#    🔹 預測為正樣本的比例: 16.43%
#    🔹 TP: 2781, FP: 6522, FN: 2684, TN: 44641

# %%
from sklearn.metrics import (
    confusion_matrix,
    precision_recall_curve,
    auc,
    classification_report,
    matthews_corrcoef,
    brier_score_loss
)

FIXED_THRESHOLD = 0.5
  # 統一使用 0.7

for model_name, score_col in models_to_analyze.items():
    print(f"\n\n{'#'*30}")
    print(f"   模型: {model_name}")
    print(f"{'#'*30}")
    
    y_pred_np = meta_test[score_col].values
    y_pred_proba = y_pred_np  # 已是機率值

    print("\n" + "=" * 70)
    print("📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC / MCC / Lift / Brier 分析")
    print("=" * 70)

    # 1. 只用 threshold = 0.7
    thr = FIXED_THRESHOLD
    y_pred_label = (y_pred_proba > thr).astype(int)
    print(f"Threshold: {thr}")
    print(classification_report(y_test_binary, y_pred_label, digits=4))

    # 2. Confusion Matrix（同樣用 0.7）
    cm = confusion_matrix(y_test_binary, y_pred_label)
    tn, fp, fn, tp = cm.ravel()

    print(f"\n📊 Confusion Matrix (threshold={thr}):")
    print("          Pred 0    Pred 1")
    print(f"True 0   {tn:7d}  {fp:7d}")
    print(f"True 1   {fn:7d}  {tp:7d}")

    # 3. Precision-Recall 曲線與 PR-AUC（和 threshold 無關）
    precision_arr, recall_arr, pr_thresholds = precision_recall_curve(y_test_binary, y_pred_np)
    pr_auc = auc(recall_arr, precision_arr)

    print("\n📊 Precision-Recall AUC:")
    print(f"   🔹 PR-AUC: {pr_auc:.4f}")
    print("   📝 解釋: 在不同 threshold 下 precision-recall 的平均表現")
    print("      對高度不平衡資料，比 ROC-AUC 更有參考價值")

    # 4. 在 threshold = 0.7 下的概覽
    pos_pred = (y_pred_label == 1).sum()
    print(f"\n📊 在 threshold = {thr} 下的概覽:")
    print(f"   🔹 正樣本實際比例: {y_test_binary.mean():.2%}")
    print(f"   🔹 預測為正樣本的比例: {pos_pred/len(y_test_binary):.2%}")
    print(f"   🔹 TP: {tp}, FP: {fp}, FN: {fn}, TN: {tn}")

    # 5. Matthews Correlation Coefficient (MCC)
    mcc = matthews_corrcoef(y_test_binary, y_pred_label)
    print(f"\n📊 Matthews Correlation Coefficient:")
    print(f"   🔹 MCC: {mcc:.4f}")

    # 6. Lift Score（使用同一個 threshold 下的 precision / base rate）
    base_rate = y_test_binary.mean()
    if pos_pred > 0:
        precision_at_thr = tp / pos_pred
        lift_score = precision_at_thr / base_rate if base_rate > 0 else np.nan
    else:
        precision_at_thr = 0.0
        lift_score = np.nan

    print("\n📊 Lift 分析 (threshold = 0.7):")
    print(f"   🔹 基準正率 (Overall Positive Rate): {base_rate:.4%}")
    print(f"   🔹 Threshold 下 precision: {precision_at_thr:.4%}")
    print(f"   🔹 Lift = precision / base_rate = {lift_score:.4f}")

    # 7. Brier Score（機率預測的均方誤差，越小越好）
    brier = brier_score_loss(y_test_binary, y_pred_proba)
    print("\n📊 Brier Score:")
    print(f"   🔹 Brier: {brier:.6f}")
# Out:
# ##############################
#    模型: XGBoost
# ##############################
#
# ======================================================================
# 📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC / MCC / Lift / Brier 分析
# ======================================================================
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0     0.9568    0.7960    0.8690     51163
#            1     0.2578    0.6633    0.3712      5465
#
#     accuracy                         0.7832     56628
#    macro avg     0.6073    0.7296    0.6201     56628
# weighted avg     0.8893    0.7832    0.8210     56628
#
#
# 📊 Confusion Matrix (threshold=0.5):
#           Pred 0    Pred 1
# True 0     40724    10439
# True 1      1840     3625
#
# 📊 Precision-Recall AUC:
#    🔹 PR-AUC: 0.3474
#    📝 解釋: 在不同 threshold 下 precision-recall 的平均表現
#       對高度不平衡資料，比 ROC-AUC 更有參考價值
#
# 📊 在 threshold = 0.5 下的概覽:
#    🔹 正樣本實際比例: 9.65%
#    🔹 預測為正樣本的比例: 24.84%
#    🔹 TP: 3625, FP: 10439, FN: 1840, TN: 40724
#
# 📊 Matthews Correlation Coefficient:
#    🔹 MCC: 0.3139
#
# 📊 Lift 分析 (threshold = 0.7):
#    🔹 基準正率 (Overall Positive Rate): 9.6507%
#    🔹 Threshold 下 precision: 25.7750%
#    🔹 Lift = precision / base_rate = 2.6708
#
# 📊 Brier Score:
#    🔹 Brier: 0.143126
#
#
# ##############################
#    模型: Logistic Regression
# ##############################
#
# ======================================================================
# 📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC / MCC / Lift / Brier 分析
# ======================================================================
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0     0.9607    0.6830    0.7984     51163
#            1     0.1993    0.7387    0.3139      5465
#
#     accuracy                         0.6884     56628
#    macro avg     0.5800    0.7108    0.5562     56628
# weighted avg     0.8873    0.6884    0.7516     56628
#
#
# 📊 Confusion Matrix (threshold=0.5):
#           Pred 0    Pred 1
# True 0     34944    16219
# True 1      1428     4037
#
# 📊 Precision-Recall AUC:
#    🔹 PR-AUC: 0.2993
#    📝 解釋: 在不同 threshold 下 precision-recall 的平均表現
#       對高度不平衡資料，比 ROC-AUC 更有參考價值
#
# 📊 在 threshold = 0.5 下的概覽:
#    🔹 正樣本實際比例: 9.65%
#    🔹 預測為正樣本的比例: 35.77%
#    🔹 TP: 4037, FP: 16219, FN: 1428, TN: 34944
#
# 📊 Matthews Correlation Coefficient:
#    🔹 MCC: 0.2598
#
# 📊 Lift 分析 (threshold = 0.7):
#    🔹 基準正率 (Overall Positive Rate): 9.6507%
#    🔹 Threshold 下 precision: 19.9299%
#    🔹 Lift = precision / base_rate = 2.0651
#
# 📊 Brier Score:
#    🔹 Brier: 0.197062
#
#
# ##############################
#    模型: Random Forest
# ##############################
#
# ======================================================================
# 📊 混淆矩陣 (Confusion Matrix) 與 PR-AUC / MCC / Lift / Brier 分析
# ======================================================================
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0     0.9587    0.7691    0.8534     51163
#            1     0.2418    0.6895    0.3580      5465
#
#     accuracy                         0.7614     56628
#    macro avg     0.6002    0.7293    0.6057     56628
# weighted avg     0.8895    0.7614    0.8056     56628
#
#
# 📊 Confusion Matrix (threshold=0.5):
#           Pred 0    Pred 1
# True 0     39347    11816
# True 1      1697     3768
#
# 📊 Precision-Recall AUC:
#    🔹 PR-AUC: 0.3322
#    📝 解釋: 在不同 threshold 下 precision-recall 的平均表現
#       對高度不平衡資料，比 ROC-AUC 更有參考價值
#
# 📊 在 threshold = 0.5 下的概覽:
#    🔹 正樣本實際比例: 9.65%
#    🔹 預測為正樣本的比例: 27.52%
#    🔹 TP: 3768, FP: 11816, FN: 1697, TN: 39347
#
# 📊 Matthews Correlation Coefficient:
#    🔹 MCC: 0.3032
#
# 📊 Lift 分析 (threshold = 0.7):
#    🔹 基準正率 (Overall Positive Rate): 9.6507%
#    🔹 Threshold 下 precision: 24.1786%
#    🔹 Lift = precision / base_rate = 2.5054
#
# 📊 Brier Score:
#    🔹 Brier: 0.157908

# %%
# ==========================================
# 12. 錯誤分析 (Error Analysis)
# ==========================================

# 設定決策閥值 (建議使用你之前實驗出的最佳值，如 0.6 或 0.7)
THRESHOLD = 0.5

print(f"📊 錯誤分析 (Threshold = {THRESHOLD})...")

# -------------------------------------------------------
# 1. 提取誤報 (False Positives, FP)
# 定義: 模型說「危險」(Score >= Thr)，但實際「安全」(Label = 0)
# -------------------------------------------------------
fp_mask = (meta_test['risk_score'] >= THRESHOLD) & (meta_test['label'] == 0)
fp_df = meta_test[fp_mask].copy()
fp_df['error_type'] = 'False Positive (誤報)'

# -------------------------------------------------------
# 2. 提取漏報 (False Negatives, FN)
# 定義: 模型說「安全」(Score < Thr)，但實際「危險」(Label > 0)
# -------------------------------------------------------
fn_mask = (meta_test['risk_score'] < THRESHOLD) & (meta_test['label'] > 0)
fn_df = meta_test[fn_mask].copy()
fn_df['error_type'] = 'False Negative (漏報)'

# 顯示統計
print(f"🔹 誤報 (FP) 筆數: {len(fp_df)}")
print(f"🔹 漏報 (FN) 筆數: {len(fn_df)}")

# -------------------------------------------------------
# 3. 進階分析：到底是「哪裡」或「何時」最容易錯？
# -------------------------------------------------------

# 轉換區域名稱以便閱讀
fp_df['Zone_Name'] = fp_df['Zone_ID'].map(zone_names)
fn_df['Zone_Name'] = fn_df['Zone_ID'].map(zone_names)

# 分析 A: 最常發生誤報的區域 (Top 5 High FP Zones)
print("\n🔴 最常「誤報」的區域 (模型太過緊張):")
print(fp_df['Zone_Name'].value_counts().head(5))

# 分析 B: 最常發生漏報的區域 (Top 5 High FN Zones)
print("\n🔵 最常「漏報」的區域 (模型太過大意):")
print(fn_df['Zone_Name'].value_counts().head(5))

# 分析 C: 最常出錯的時段 (小時)
fp_df['Hour'] = fp_df['Slot_Start'].dt.hour
fn_df['Hour'] = fn_df['Slot_Start'].dt.hour

print("\n⏰ 誤報好發時間 (Hour):")
print(fp_df['Hour'].value_counts().sort_index())

print("\n⏰ 漏報好發時間 (Hour):")
print(fn_df['Hour'].value_counts().sort_index())

# -------------------------------------------------------
# 4. 匯出錯誤資料供進一步檢查
# -------------------------------------------------------
error_analysis_df = pd.concat([fp_df, fn_df])
error_analysis_df.to_csv('error_analysis.csv', index=False, encoding='utf-8-sig')
print("\n✅ 已匯出錯誤分析檔案: error_analysis.csv")

# 查看範例
print("\n📝 誤報範例 (預測很高分，但沒事):")
print(fp_df.sort_values('risk_score', ascending=False).head(3)[['Slot_Start', 'Zone_Name', 'risk_score', 'label']])

print("\n📝 漏報範例 (預測很低分，卻被抓):")
print(fn_df.sort_values('risk_score', ascending=True).head(3)[['Slot_Start', 'Zone_Name', 'risk_score', 'label']])
# Out:
# 📊 錯誤分析 (Threshold = 0.5)...
# 🔹 誤報 (FP) 筆數: 10439
# 🔹 漏報 (FN) 筆數: 1840
#
# 🔴 最常「誤報」的區域 (模型太過緊張):
# Zone_Name
# 大門口附近    1112
# 管停       1004
# 社科院       944
# 理工區       911
# 電資附近      850
# Name: count, dtype: int64
#
# 🔵 最常「漏報」的區域 (模型太過大意):
# Zone_Name
# 武嶺外面     171
# 生科附近     164
# 翠嶺道      163
# 翠亨宿舍西    127
# 海科院      102
# Name: count, dtype: int64
#
# ⏰ 誤報好發時間 (Hour):
# Hour
# 9     2725
# 10    1278
# 11     143
# 13    3048
# 14    2372
# 15     848
# 16      25
# Name: count, dtype: int64
#
# ⏰ 漏報好發時間 (Hour):
# Hour
# 9     379
# 10    474
# 11    132
# 13    273
# 14    285
# 15    271
# 16     26
# Name: count, dtype: int64
#
# ✅ 已匯出錯誤分析檔案: error_analysis.csv
#
# 📝 誤報範例 (預測很高分，但沒事):
#                 Slot_Start Zone_Name  risk_score  label
# 217581 2025-09-19 13:30:00     大門口附近    0.970802      0
# 410573 2025-11-03 10:45:00      電資附近    0.967538      0
# 409215 2025-09-12 09:15:00      電資附近    0.966332      0
#
# 📝 漏報範例 (預測很低分，卻被抓):
#                 Slot_Start Zone_Name  risk_score  label
# 246189 2025-11-04 15:30:00      運動場區    0.005419      1
# 246188 2025-11-04 15:15:00      運動場區    0.005652      1
# 246185 2025-11-04 14:30:00      運動場區    0.005897      1

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

# 設定繪圖風格
plt.style.use('ggplot')
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']  # 確保中文正常顯示
plt.rcParams['axes.unicode_minus'] = False

# ==========================================
# 1. 繪製 Gain (平均獲利) - 最推薦
# 意義: 該特徵每次被用來切分時，平均能降低多少 Loss (提升多少準度)
# ==========================================
fig, ax = plt.subplots(figsize=(12, 8))
xgb.plot_importance(model, importance_type='gain', max_num_features=15, height=0.5, ax=ax, color='skyblue')
plt.title('feature importance (Gain) ')
plt.xlabel('F Score (Gain)')
plt.show()

# ==========================================
# 2. 繪製 Weight (使用頻率)
# 意義: 該特徵在所有樹中被選為切分點的總次數
# ==========================================
fig, ax = plt.subplots(figsize=(12, 8))
xgb.plot_importance(model, importance_type='weight', max_num_features=15, height=0.5, ax=ax, color='lightcoral')
plt.title('feature importance (Weight) - Who is used most frequently')
plt.xlabel('F Score (Weight)')
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei

# %%
# 需要先安裝: pip install shap
import shap

# 初始化解釋器
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# 1. 摘要圖 (Summary Plot) - 這是最強大的圖
# 紅色代表數值高，藍色代表數值低；向右代表風險高，向左代表風險低
plt.figure()
shap.summary_plot(shap_values, X_test, plot_type="dot", max_display=15)

# 2. 條狀圖 (Bar Plot) - 類似 Gain，但更公平
plt.figure()
shap.summary_plot(shap_values, X_test, plot_type="bar", max_display=15)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Microsoft JhengHei
